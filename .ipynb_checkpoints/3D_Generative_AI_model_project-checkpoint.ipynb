# %%
pip install matplotlib tensorflow-datasets ipywidgets tensorflow matplotlib "protobuf<=3.20.1"
# Out:
# Requirement already satisfied: matplotlib in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (3.7.1)
# Requirement already satisfied: tensorflow-datasets in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (4.9.2)
# Requirement already satisfied: ipywidgets in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (8.0.6)
# Requirement already satisfied: tensorflow in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (2.9.0)
# Requirement already satisfied: protobuf<=3.20.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (3.20.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: absl-py in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-datasets) (1.4.0)
# Requirement already satisfied: array-record in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-datasets) (0.2.0)
# Requirement already satisfied: click in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-datasets) (8.1.3)
# Requirement already satisfied: dm-tree in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-datasets) (0.1.8)
# Requirement already satisfied: etils[enp,epath]>=0.9.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-datasets) (1.2.0)
# Requirement already satisfied: promise in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-datasets) (2.3)
# Requirement already satisfied: psutil in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-datasets) (5.9.5)
# Requirement already satisfied: requests>=2.19.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-datasets) (2.28.2)
# Requirement already satisfied: tensorflow-metadata in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-datasets) (1.13.0)
# Requirement already satisfied: termcolor in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-datasets) (2.3.0)
# Requirement already satisfied: toml in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-datasets) (0.10.2)
# Requirement already satisfied: tqdm in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-datasets) (4.65.0)
# Requirement already satisfied: wrapt in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-datasets) (1.14.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipywidgets) (6.22.0)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipywidgets) (8.12.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipywidgets) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipywidgets) (4.0.7)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipywidgets) (3.0.7)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: setuptools in c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow) (66.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow) (1.54.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: importlib_resources in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets) (5.12.0)
# Requirement already satisfied: zipp in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets) (3.15.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (8.2.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: pyzmq>=20 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (25.0.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.3.1)
# Requirement already satisfied: backcall in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: pickleshare in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: colorama in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.19.0->tensorflow-datasets) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.19.0->tensorflow-datasets) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.19.0->tensorflow-datasets) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.19.0->tensorflow-datasets) (2022.12.7)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.2.3)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-metadata->tensorflow-datasets) (1.56.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets) (3.2.0)
# Requirement already satisfied: pywin32>=300 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets) (306)
# Requirement already satisfied: wcwidth in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.6)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow) (2.1.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -otobuf (c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -otobuf (c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
#
# [notice] A new release of pip is available: 23.1.1 -> 23.1.2
# [notice] To update, run: C:\Users\xxalh\miniconda3\envs\tensorflow\python.exe -m pip install --upgrade pip

# %%
conda install -c conda-forge cudatoolkit=11.2 cudnn=8.1.0
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow_graphics
# Out:
# Collecting tensorflow_graphics
#   Using cached tensorflow_graphics-2021.12.3-py3-none-any.whl (4.3 MB)
# Requirement already satisfied: tensorflow>=2.2.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow_graphics) (2.9.0)
# Collecting tensorflow-addons>=0.10.0 (from tensorflow_graphics)
#   Using cached tensorflow_addons-0.20.0-cp310-cp310-win_amd64.whl (736 kB)
# Requirement already satisfied: tensorflow-datasets>=2.0.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow_graphics) (4.9.2)
# Requirement already satisfied: absl-py>=0.6.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow_graphics) (1.4.0)
# Requirement already satisfied: h5py>=2.10.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow_graphics) (3.8.0)
# Requirement already satisfied: matplotlib>=2.2.5 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow_graphics) (3.7.1)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow_graphics) (1.23.5)
# Requirement already satisfied: psutil>=5.7.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow_graphics) (5.9.5)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow_graphics) (1.10.1)
# Requirement already satisfied: tqdm>=4.45.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow_graphics) (4.65.0)
# Collecting OpenEXR>=1.3.2 (from tensorflow_graphics)
#   Using cached OpenEXR-1.3.9.tar.gz (13 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow_graphics) (2.3.0)
# Requirement already satisfied: trimesh>=2.37.22 in c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow_graphics) (3.21.6)
# Requirement already satisfied: networkx in c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow_graphics) (3.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.2.5->tensorflow_graphics) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.2.5->tensorflow_graphics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.2.5->tensorflow_graphics) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.2.5->tensorflow_graphics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.2.5->tensorflow_graphics) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.2.5->tensorflow_graphics) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.2.5->tensorflow_graphics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.2.5->tensorflow_graphics) (2.8.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow>=2.2.0->tensorflow_graphics) (1.6.3)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow>=2.2.0->tensorflow_graphics) (1.12)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow>=2.2.0->tensorflow_graphics) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow>=2.2.0->tensorflow_graphics) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow>=2.2.0->tensorflow_graphics) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow>=2.2.0->tensorflow_graphics) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow>=2.2.0->tensorflow_graphics) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow>=2.2.0->tensorflow_graphics) (3.20.1)
# Requirement already satisfied: setuptools in c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages (from tensorflow>=2.2.0->tensorflow_graphics) (66.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow>=2.2.0->tensorflow_graphics) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow>=2.2.0->tensorflow_graphics) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow>=2.2.0->tensorflow_graphics) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow>=2.2.0->tensorflow_graphics) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow>=2.2.0->tensorflow_graphics) (1.54.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow>=2.2.0->tensorflow_graphics) (2.9.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow>=2.2.0->tensorflow_graphics) (2.9.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow>=2.2.0->tensorflow_graphics) (2.9.0)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons>=0.10.0->tensorflow_graphics)
#   Using cached typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: array-record in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-datasets>=2.0.0->tensorflow_graphics) (0.2.0)
# Requirement already satisfied: click in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-datasets>=2.0.0->tensorflow_graphics) (8.1.3)
# Requirement already satisfied: dm-tree in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-datasets>=2.0.0->tensorflow_graphics) (0.1.8)
# Requirement already satisfied: etils[enp,epath]>=0.9.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-datasets>=2.0.0->tensorflow_graphics) (1.2.0)
# Requirement already satisfied: promise in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-datasets>=2.0.0->tensorflow_graphics) (2.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-datasets>=2.0.0->tensorflow_graphics) (2.28.2)
# Requirement already satisfied: tensorflow-metadata in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-datasets>=2.0.0->tensorflow_graphics) (1.13.0)
# Requirement already satisfied: toml in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-datasets>=2.0.0->tensorflow_graphics) (0.10.2)
# Requirement already satisfied: colorama in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tqdm>=4.45.0->tensorflow_graphics) (0.4.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from astunparse>=1.6.0->tensorflow>=2.2.0->tensorflow_graphics) (0.40.0)
# Requirement already satisfied: importlib_resources in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets>=2.0.0->tensorflow_graphics) (5.12.0)
# Requirement already satisfied: zipp in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets>=2.0.0->tensorflow_graphics) (3.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.19.0->tensorflow-datasets>=2.0.0->tensorflow_graphics) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.19.0->tensorflow-datasets>=2.0.0->tensorflow_graphics) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.19.0->tensorflow-datasets>=2.0.0->tensorflow_graphics) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.19.0->tensorflow-datasets>=2.0.0->tensorflow_graphics) (2022.12.7)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.2.0->tensorflow_graphics) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.2.0->tensorflow_graphics) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.2.0->tensorflow_graphics) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.2.0->tensorflow_graphics) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.2.0->tensorflow_graphics) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.2.0->tensorflow_graphics) (2.2.3)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorflow-metadata->tensorflow-datasets>=2.0.0->tensorflow_graphics) (1.56.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.2.0->tensorflow_graphics) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.2.0->tensorflow_graphics) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.2.0->tensorflow_graphics) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.2.0->tensorflow_graphics) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow>=2.2.0->tensorflow_graphics) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.2.0->tensorflow_graphics) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.2.0->tensorflow_graphics) (3.2.2)
# Building wheels for collected packages: OpenEXR
#   Building wheel for OpenEXR (setup.py): started
#   Building wheel for OpenEXR (setup.py): finished with status 'error'
#   Running setup.py clean for OpenEXR
# Failed to build OpenEXR
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -otobuf (c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages)
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [5 lines of output]
#   Looking for libOpenEXR...
#   cl : Command line warning D9002 : ignoring unknown option '-g'
#   OpenEXR.cpp
#   OpenEXR.cpp(36): fatal error C1083: Cannot open include file: 'ImfIO.h': No such file or directory
#   error: command 'C:\\Program Files\\Microsoft Visual Studio\\2022\\Community\\VC\\Tools\\MSVC\\14.34.31933\\bin\\HostX86\\x64\\cl.exe' failed with exit code 2
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for OpenEXR
# ERROR: Could not build wheels for OpenEXR, which is required to install pyproject.toml-based projects
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
#
# [notice] A new release of pip is available: 23.1.1 -> 23.1.2
# [notice] To update, run: C:\Users\xxalh\miniconda3\envs\tensorflow\python.exe -m pip install --upgrade pip

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from opencv-python) (1.23.5)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -otobuf (c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -otobuf (c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
#
# [notice] A new release of pip is available: 23.1.1 -> 23.1.2
# [notice] To update, run: C:\Users\xxalh\miniconda3\envs\tensorflow\python.exe -m pip install --upgrade pip

# %%
# !pip3 install skimage
# Out:
# Collecting skimage
#   Using cached skimage-0.0.tar.gz (757 bytes)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [3 lines of output]
#
#   *** Please install the `scikit-image` package (instead of `skimage`) ***
#
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
#
# [notice] A new release of pip is available: 23.1.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
conda install -c conda-forge scikit-image
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge trimesh
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "pyglet<2"
# Out:
# Requirement already satisfied: pyglet<2 in c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages (1.5.27)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -otobuf (c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -otobuf (c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
#
# [notice] A new release of pip is available: 23.1.1 -> 23.1.2
# [notice] To update, run: C:\Users\xxalh\miniconda3\envs\tensorflow\python.exe -m pip install --upgrade pip

# %%
conda install pydot
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\xxalh\miniconda3\envs\tensorflow
#
#   added / updated specs:
#     - pydot
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     graphviz-2.38              |       hfd603c8_2        29.3 MB
#     pydot-1.4.2                |  py310haa95532_0          46 KB
#     pyparsing-2.4.7            |     pyhd3eb1b0_0          59 KB
#     ------------------------------------------------------------
#                                            Total:        29.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   graphviz           pkgs/main/win-64::graphviz-2.38-hfd603c8_2
#   pydot              pkgs/main/win-64::pydot-1.4.2-py310haa95532_0
#   pyparsing          pkgs/main/noarch::pyparsing-2.4.7-pyhd3eb1b0_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2023.5.7~ --> pkgs/main::ca-certificates-2023.01.10-haa95532_0
#   certifi            conda-forge/noarch::certifi-2023.5.7-~ --> pkgs/main/win-64::certifi-2022.12.7-py310haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# pydot-1.4.2          | 46 KB     |            |   0%
#
# graphviz-2.38        | 29.3 MB   |            |   0%
#
#
# pyparsing-2.4.7      | 59 KB     |            |   0%
#
#
# pyparsing-2.4.7      | 59 KB     | ##6        |  27%
#
#
# pyparsing-2.4.7      | 59 KB     | #####3     |  54%
#
#
# pyparsing-2.4.7      | 59 KB     | ########## | 100%
#
#
# pyparsing-2.4.7      | 59 KB     | ########## | 100%
# pydot-1.4.2          | 46 KB     | ###4       |  34%
# pydot-1.4.2          | 46 KB     | ########## | 100%
#
# graphviz-2.38        | 29.3 MB   |            |   0%
#
# graphviz-2.38        | 29.3 MB   |            |   0%
#
# graphviz-2.38        | 29.3 MB   |            |   1%
#
# graphviz-2.38        | 29.3 MB   |            |   1%
#
# graphviz-2.38        | 29.3 MB   | 1          |   1%
#
# graphviz-2.38        | 29.3 MB   | 1          |   1%
#
# graphviz-2.38        | 29.3 MB   | 1          |   1%
#
# graphviz-2.38        | 29.3 MB   | 1          |   2%
#
# graphviz-2.38        | 29.3 MB   | 2          |   2%
#
# graphviz-2.38        | 29.3 MB   | 2          |   3%
#
# graphviz-2.38        | 29.3 MB   | 2          |   3%
#
# graphviz-2.38        | 29.3 MB   | 3          |   3%
#
# graphviz-2.38        | 29.3 MB   | 3          |   4%
#
# graphviz-2.38        | 29.3 MB   | 3          |   4%
#
# graphviz-2.38        | 29.3 MB   | 4          |   4%
#
# graphviz-2.38        | 29.3 MB   | 4          |   5%
#
# graphviz-2.38        | 29.3 MB   | 4          |   5%
#
# graphviz-2.38        | 29.3 MB   | 5          |   5%
#
# graphviz-2.38        | 29.3 MB   | 5          |   5%
#
# graphviz-2.38        | 29.3 MB   | 5          |   6%
#
# graphviz-2.38        | 29.3 MB   | 6          |   6%
#
# graphviz-2.38        | 29.3 MB   | 6          |   7%
#
# graphviz-2.38        | 29.3 MB   | 6          |   7%
#
# graphviz-2.38        | 29.3 MB   | 7          |   7%
#
# graphviz-2.38        | 29.3 MB   | 7          |   7%
#
# graphviz-2.38        | 29.3 MB   | 7          |   8%
#
# graphviz-2.38        | 29.3 MB   | 7          |   8%
#
# graphviz-2.38        | 29.3 MB   | 8          |   8%
#
# graphviz-2.38        | 29.3 MB   | 8          |   8%
#
# graphviz-2.38        | 29.3 MB   | 8          |   9%
#
# graphviz-2.38        | 29.3 MB   | 8          |   9%
#
# graphviz-2.38        | 29.3 MB   | 9          |   9%
#
# graphviz-2.38        | 29.3 MB   | 9          |   9%
#
# graphviz-2.38        | 29.3 MB   | 9          |  10%
#
# graphviz-2.38        | 29.3 MB   | 9          |  10%
#
# graphviz-2.38        | 29.3 MB   | #          |  10%
#
# graphviz-2.38        | 29.3 MB   | #          |  10%
#
# graphviz-2.38        | 29.3 MB   | #          |  11%
#
# graphviz-2.38        | 29.3 MB   | #          |  11%
#
# graphviz-2.38        | 29.3 MB   | #1         |  11%
#
# graphviz-2.38        | 29.3 MB   | #1         |  11%
#
# graphviz-2.38        | 29.3 MB   | #1         |  12%
#
# graphviz-2.38        | 29.3 MB   | #2         |  12%
#
# graphviz-2.38        | 29.3 MB   | #2         |  12%
#
# graphviz-2.38        | 29.3 MB   | #2         |  13%
#
# graphviz-2.38        | 29.3 MB   | #3         |  13%
#
# graphviz-2.38        | 29.3 MB   | #3         |  13%
#
# graphviz-2.38        | 29.3 MB   | #3         |  14%
#
# graphviz-2.38        | 29.3 MB   | #3         |  14%
#
# graphviz-2.38        | 29.3 MB   | #4         |  14%
#
# graphviz-2.38        | 29.3 MB   | #4         |  14%
#
# graphviz-2.38        | 29.3 MB   | #4         |  15%
#
# graphviz-2.38        | 29.3 MB   | #4         |  15%
#
# graphviz-2.38        | 29.3 MB   | #5         |  15%
#
# graphviz-2.38        | 29.3 MB   | #5         |  15%
#
# graphviz-2.38        | 29.3 MB   | #5         |  15%
#
# graphviz-2.38        | 29.3 MB   | #5         |  16%
#
# graphviz-2.38        | 29.3 MB   | #5         |  16%
#
# graphviz-2.38        | 29.3 MB   | #6         |  16%
#
# graphviz-2.38        | 29.3 MB   | #6         |  16%
#
# graphviz-2.38        | 29.3 MB   | #6         |  17%
#
# graphviz-2.38        | 29.3 MB   | #7         |  17%
#
# graphviz-2.38        | 29.3 MB   | #7         |  17%
#
# graphviz-2.38        | 29.3 MB   | #7         |  18%
#
# graphviz-2.38        | 29.3 MB   | #8         |  18%
#
# graphviz-2.38        | 29.3 MB   | #8         |  18%
#
# graphviz-2.38        | 29.3 MB   | #8         |  19%
#
# graphviz-2.38        | 29.3 MB   | #8         |  19%
#
# graphviz-2.38        | 29.3 MB   | #9         |  19%
#
# graphviz-2.38        | 29.3 MB   | #9         |  20%
#
# graphviz-2.38        | 29.3 MB   | #9         |  20%
#
# graphviz-2.38        | 29.3 MB   | ##         |  20%
#
# graphviz-2.38        | 29.3 MB   | ##         |  20%
#
# graphviz-2.38        | 29.3 MB   | ##         |  21%
#
# graphviz-2.38        | 29.3 MB   | ##         |  21%
#
# graphviz-2.38        | 29.3 MB   | ##1        |  21%
#
# graphviz-2.38        | 29.3 MB   | ##1        |  21%
#
# graphviz-2.38        | 29.3 MB   | ##1        |  21%
#
# graphviz-2.38        | 29.3 MB   | ##1        |  22%
#
# graphviz-2.38        | 29.3 MB   | ##2        |  22%
#
# graphviz-2.38        | 29.3 MB   | ##2        |  22%
#
# graphviz-2.38        | 29.3 MB   | ##2        |  22%
#
# graphviz-2.38        | 29.3 MB   | ##2        |  23%
#
# graphviz-2.38        | 29.3 MB   | ##3        |  23%
#
# graphviz-2.38        | 29.3 MB   | ##3        |  23%
#
# graphviz-2.38        | 29.3 MB   | ##3        |  24%
#
# graphviz-2.38        | 29.3 MB   | ##3        |  24%
#
# graphviz-2.38        | 29.3 MB   | ##4        |  24%
#
# graphviz-2.38        | 29.3 MB   | ##4        |  24%
#
# graphviz-2.38        | 29.3 MB   | ##4        |  25%
#
# graphviz-2.38        | 29.3 MB   | ##4        |  25%
#
# graphviz-2.38        | 29.3 MB   | ##5        |  25%
#
# graphviz-2.38        | 29.3 MB   | ##5        |  25%
#
# graphviz-2.38        | 29.3 MB   | ##5        |  26%
#
# graphviz-2.38        | 29.3 MB   | ##5        |  26%
#
# graphviz-2.38        | 29.3 MB   | ##6        |  26%
#
# graphviz-2.38        | 29.3 MB   | ##6        |  26%
#
# graphviz-2.38        | 29.3 MB   | ##6        |  27%
#
# graphviz-2.38        | 29.3 MB   | ##6        |  27%
#
# graphviz-2.38        | 29.3 MB   | ##6        |  27%
#
# graphviz-2.38        | 29.3 MB   | ##7        |  27%
#
# graphviz-2.38        | 29.3 MB   | ##7        |  27%
#
# graphviz-2.38        | 29.3 MB   | ##7        |  28%
#
# graphviz-2.38        | 29.3 MB   | ##7        |  28%
#
# graphviz-2.38        | 29.3 MB   | ##7        |  28%
#
# graphviz-2.38        | 29.3 MB   | ##8        |  28%
#
# graphviz-2.38        | 29.3 MB   | ##8        |  28%
#
# graphviz-2.38        | 29.3 MB   | ##8        |  28%
#
# graphviz-2.38        | 29.3 MB   | ##8        |  29%
#
# graphviz-2.38        | 29.3 MB   | ##8        |  29%
#
# graphviz-2.38        | 29.3 MB   | ##8        |  29%
#
# graphviz-2.38        | 29.3 MB   | ##9        |  29%
#
# graphviz-2.38        | 29.3 MB   | ##9        |  29%
#
# graphviz-2.38        | 29.3 MB   | ##9        |  29%
#
# graphviz-2.38        | 29.3 MB   | ##9        |  30%
#
# graphviz-2.38        | 29.3 MB   | ##9        |  30%
#
# graphviz-2.38        | 29.3 MB   | ###        |  30%
#
# graphviz-2.38        | 29.3 MB   | ###        |  30%
#
# graphviz-2.38        | 29.3 MB   | ###        |  31%
#
# graphviz-2.38        | 29.3 MB   | ###        |  31%
#
# graphviz-2.38        | 29.3 MB   | ###1       |  31%
#
# graphviz-2.38        | 29.3 MB   | ###1       |  32%
#
# graphviz-2.38        | 29.3 MB   | ###1       |  32%
#
# graphviz-2.38        | 29.3 MB   | ###1       |  32%
#
# graphviz-2.38        | 29.3 MB   | ###2       |  32%
#
# graphviz-2.38        | 29.3 MB   | ###2       |  32%
#
# graphviz-2.38        | 29.3 MB   | ###2       |  33%
#
# graphviz-2.38        | 29.3 MB   | ###2       |  33%
#
# graphviz-2.38        | 29.3 MB   | ###3       |  33%
#
# graphviz-2.38        | 29.3 MB   | ###3       |  33%
#
# graphviz-2.38        | 29.3 MB   | ###3       |  34%
#
# graphviz-2.38        | 29.3 MB   | ###3       |  34%
#
# graphviz-2.38        | 29.3 MB   | ###4       |  34%
#
# graphviz-2.38        | 29.3 MB   | ###4       |  34%
#
# graphviz-2.38        | 29.3 MB   | ###4       |  35%
#
# graphviz-2.38        | 29.3 MB   | ###5       |  35%
#
# graphviz-2.38        | 29.3 MB   | ###5       |  36%
#
# graphviz-2.38        | 29.3 MB   | ###5       |  36%
#
# graphviz-2.38        | 29.3 MB   | ###6       |  36%
#
# graphviz-2.38        | 29.3 MB   | ###6       |  37%
#
# graphviz-2.38        | 29.3 MB   | ###6       |  37%
#
# graphviz-2.38        | 29.3 MB   | ###7       |  37%
#
# graphviz-2.38        | 29.3 MB   | ###7       |  37%
#
# graphviz-2.38        | 29.3 MB   | ###7       |  38%
#
# graphviz-2.38        | 29.3 MB   | ###7       |  38%
#
# graphviz-2.38        | 29.3 MB   | ###8       |  38%
#
# graphviz-2.38        | 29.3 MB   | ###8       |  38%
#
# graphviz-2.38        | 29.3 MB   | ###8       |  39%
#
# graphviz-2.38        | 29.3 MB   | ###8       |  39%
#
# graphviz-2.38        | 29.3 MB   | ###9       |  39%
#
# graphviz-2.38        | 29.3 MB   | ###9       |  39%
#
# graphviz-2.38        | 29.3 MB   | ###9       |  40%
#
# graphviz-2.38        | 29.3 MB   | ###9       |  40%
#
# graphviz-2.38        | 29.3 MB   | ###9       |  40%
#
# graphviz-2.38        | 29.3 MB   | ####       |  40%
#
# graphviz-2.38        | 29.3 MB   | ####       |  40%
#
# graphviz-2.38        | 29.3 MB   | ####       |  40%
#
# graphviz-2.38        | 29.3 MB   | ####       |  41%
#
# graphviz-2.38        | 29.3 MB   | ####       |  41%
#
# graphviz-2.38        | 29.3 MB   | ####1      |  41%
#
# graphviz-2.38        | 29.3 MB   | ####1      |  41%
#
# graphviz-2.38        | 29.3 MB   | ####1      |  41%
#
# graphviz-2.38        | 29.3 MB   | ####1      |  42%
#
# graphviz-2.38        | 29.3 MB   | ####1      |  42%
#
# graphviz-2.38        | 29.3 MB   | ####1      |  42%
#
# graphviz-2.38        | 29.3 MB   | ####2      |  42%
#
# graphviz-2.38        | 29.3 MB   | ####2      |  42%
#
# graphviz-2.38        | 29.3 MB   | ####2      |  42%
#
# graphviz-2.38        | 29.3 MB   | ####2      |  43%
#
# graphviz-2.38        | 29.3 MB   | ####2      |  43%
#
# graphviz-2.38        | 29.3 MB   | ####3      |  43%
#
# graphviz-2.38        | 29.3 MB   | ####3      |  43%
#
# graphviz-2.38        | 29.3 MB   | ####3      |  43%
#
# graphviz-2.38        | 29.3 MB   | ####3      |  44%
#
# graphviz-2.38        | 29.3 MB   | ####3      |  44%
#
# graphviz-2.38        | 29.3 MB   | ####4      |  44%
#
# graphviz-2.38        | 29.3 MB   | ####4      |  44%
#
# graphviz-2.38        | 29.3 MB   | ####4      |  44%
#
# graphviz-2.38        | 29.3 MB   | ####4      |  45%
#
# graphviz-2.38        | 29.3 MB   | ####5      |  45%
#
# graphviz-2.38        | 29.3 MB   | ####5      |  45%
#
# graphviz-2.38        | 29.3 MB   | ####5      |  46%
#
# graphviz-2.38        | 29.3 MB   | ####5      |  46%
#
# graphviz-2.38        | 29.3 MB   | ####6      |  46%
#
# graphviz-2.38        | 29.3 MB   | ####6      |  47%
#
# graphviz-2.38        | 29.3 MB   | ####6      |  47%
#
# graphviz-2.38        | 29.3 MB   | ####7      |  47%
#
# graphviz-2.38        | 29.3 MB   | ####7      |  47%
#
# graphviz-2.38        | 29.3 MB   | ####7      |  48%
#
# graphviz-2.38        | 29.3 MB   | ####8      |  48%
#
# graphviz-2.38        | 29.3 MB   | ####8      |  48%
#
# graphviz-2.38        | 29.3 MB   | ####8      |  48%
#
# graphviz-2.38        | 29.3 MB   | ####8      |  49%
#
# graphviz-2.38        | 29.3 MB   | ####9      |  49%
#
# graphviz-2.38        | 29.3 MB   | ####9      |  49%
#
# graphviz-2.38        | 29.3 MB   | ####9      |  50%
#
# graphviz-2.38        | 29.3 MB   | ####9      |  50%
#
# graphviz-2.38        | 29.3 MB   | #####      |  50%
#
# graphviz-2.38        | 29.3 MB   | #####      |  51%
#
# graphviz-2.38        | 29.3 MB   | #####1     |  51%
#
# graphviz-2.38        | 29.3 MB   | #####1     |  52%
#
# graphviz-2.38        | 29.3 MB   | #####1     |  52%
#
# graphviz-2.38        | 29.3 MB   | #####2     |  52%
#
# graphviz-2.38        | 29.3 MB   | #####2     |  52%
#
# graphviz-2.38        | 29.3 MB   | #####2     |  53%
#
# graphviz-2.38        | 29.3 MB   | #####2     |  53%
#
# graphviz-2.38        | 29.3 MB   | #####3     |  53%
#
# graphviz-2.38        | 29.3 MB   | #####3     |  53%
#
# graphviz-2.38        | 29.3 MB   | #####3     |  54%
#
# graphviz-2.38        | 29.3 MB   | #####4     |  54%
#
# graphviz-2.38        | 29.3 MB   | #####4     |  54%
#
# graphviz-2.38        | 29.3 MB   | #####5     |  55%
#
# graphviz-2.38        | 29.3 MB   | #####5     |  55%
#
# graphviz-2.38        | 29.3 MB   | #####5     |  56%
#
# graphviz-2.38        | 29.3 MB   | #####5     |  56%
#
# graphviz-2.38        | 29.3 MB   | #####6     |  56%
#
# graphviz-2.38        | 29.3 MB   | #####6     |  56%
#
# graphviz-2.38        | 29.3 MB   | #####6     |  57%
#
# graphviz-2.38        | 29.3 MB   | #####7     |  57%
#
# graphviz-2.38        | 29.3 MB   | #####7     |  57%
#
# graphviz-2.38        | 29.3 MB   | #####7     |  57%
#
# graphviz-2.38        | 29.3 MB   | #####7     |  58%
#
# graphviz-2.38        | 29.3 MB   | #####8     |  58%
#
# graphviz-2.38        | 29.3 MB   | #####8     |  58%
#
# graphviz-2.38        | 29.3 MB   | #####8     |  59%
#
# graphviz-2.38        | 29.3 MB   | #####8     |  59%
#
# graphviz-2.38        | 29.3 MB   | #####9     |  59%
#
# graphviz-2.38        | 29.3 MB   | #####9     |  59%
#
# graphviz-2.38        | 29.3 MB   | #####9     |  60%
#
# graphviz-2.38        | 29.3 MB   | #####9     |  60%
#
# graphviz-2.38        | 29.3 MB   | ######     |  60%
#
# graphviz-2.38        | 29.3 MB   | ######     |  60%
#
# graphviz-2.38        | 29.3 MB   | ######     |  61%
#
# graphviz-2.38        | 29.3 MB   | ######     |  61%
#
# graphviz-2.38        | 29.3 MB   | ######1    |  61%
#
# graphviz-2.38        | 29.3 MB   | ######1    |  61%
#
# graphviz-2.38        | 29.3 MB   | ######1    |  62%
#
# graphviz-2.38        | 29.3 MB   | ######1    |  62%
#
# graphviz-2.38        | 29.3 MB   | ######2    |  62%
#
# graphviz-2.38        | 29.3 MB   | ######2    |  63%
#
# graphviz-2.38        | 29.3 MB   | ######3    |  63%
#
# graphviz-2.38        | 29.3 MB   | ######3    |  63%
#
# graphviz-2.38        | 29.3 MB   | ######3    |  64%
#
# graphviz-2.38        | 29.3 MB   | ######3    |  64%
#
# graphviz-2.38        | 29.3 MB   | ######4    |  64%
#
# graphviz-2.38        | 29.3 MB   | ######4    |  64%
#
# graphviz-2.38        | 29.3 MB   | ######4    |  64%
#
# graphviz-2.38        | 29.3 MB   | ######4    |  65%
#
# graphviz-2.38        | 29.3 MB   | ######5    |  65%
#
# graphviz-2.38        | 29.3 MB   | ######5    |  65%
#
# graphviz-2.38        | 29.3 MB   | ######5    |  66%
#
# graphviz-2.38        | 29.3 MB   | ######5    |  66%
#
# graphviz-2.38        | 29.3 MB   | ######5    |  66%
#
# graphviz-2.38        | 29.3 MB   | ######6    |  66%
#
# graphviz-2.38        | 29.3 MB   | ######6    |  66%
#
# graphviz-2.38        | 29.3 MB   | ######6    |  66%
#
# graphviz-2.38        | 29.3 MB   | ######6    |  67%
#
# graphviz-2.38        | 29.3 MB   | ######6    |  67%
#
# graphviz-2.38        | 29.3 MB   | ######6    |  67%
#
# graphviz-2.38        | 29.3 MB   | ######7    |  67%
#
# graphviz-2.38        | 29.3 MB   | ######7    |  67%
#
# graphviz-2.38        | 29.3 MB   | ######7    |  67%
#
# graphviz-2.38        | 29.3 MB   | ######7    |  68%
#
# graphviz-2.38        | 29.3 MB   | ######7    |  68%
#
# graphviz-2.38        | 29.3 MB   | ######8    |  68%
#
# graphviz-2.38        | 29.3 MB   | ######8    |  68%
#
# graphviz-2.38        | 29.3 MB   | ######8    |  68%
#
# graphviz-2.38        | 29.3 MB   | ######8    |  69%
#
# graphviz-2.38        | 29.3 MB   | ######8    |  69%
#
# graphviz-2.38        | 29.3 MB   | ######9    |  69%
#
# graphviz-2.38        | 29.3 MB   | ######9    |  69%
#
# graphviz-2.38        | 29.3 MB   | ######9    |  70%
#
# graphviz-2.38        | 29.3 MB   | ######9    |  70%
#
# graphviz-2.38        | 29.3 MB   | #######    |  70%
#
# graphviz-2.38        | 29.3 MB   | #######    |  71%
#
# graphviz-2.38        | 29.3 MB   | #######    |  71%
#
# graphviz-2.38        | 29.3 MB   | #######    |  71%
#
# graphviz-2.38        | 29.3 MB   | #######1   |  71%
#
# graphviz-2.38        | 29.3 MB   | #######1   |  72%
#
# graphviz-2.38        | 29.3 MB   | #######1   |  72%
#
# graphviz-2.38        | 29.3 MB   | #######1   |  72%
#
# graphviz-2.38        | 29.3 MB   | #######2   |  72%
#
# graphviz-2.38        | 29.3 MB   | #######2   |  72%
#
# graphviz-2.38        | 29.3 MB   | #######2   |  73%
#
# graphviz-2.38        | 29.3 MB   | #######2   |  73%
#
# graphviz-2.38        | 29.3 MB   | #######3   |  73%
#
# graphviz-2.38        | 29.3 MB   | #######3   |  73%
#
# graphviz-2.38        | 29.3 MB   | #######3   |  74%
#
# graphviz-2.38        | 29.3 MB   | #######3   |  74%
#
# graphviz-2.38        | 29.3 MB   | #######4   |  74%
#
# graphviz-2.38        | 29.3 MB   | #######4   |  74%
#
# graphviz-2.38        | 29.3 MB   | #######4   |  75%
#
# graphviz-2.38        | 29.3 MB   | #######4   |  75%
#
# graphviz-2.38        | 29.3 MB   | #######5   |  75%
#
# graphviz-2.38        | 29.3 MB   | #######5   |  75%
#
# graphviz-2.38        | 29.3 MB   | #######5   |  76%
#
# graphviz-2.38        | 29.3 MB   | #######6   |  76%
#
# graphviz-2.38        | 29.3 MB   | #######6   |  76%
#
# graphviz-2.38        | 29.3 MB   | #######6   |  77%
#
# graphviz-2.38        | 29.3 MB   | #######6   |  77%
#
# graphviz-2.38        | 29.3 MB   | #######7   |  77%
#
# graphviz-2.38        | 29.3 MB   | #######7   |  77%
#
# graphviz-2.38        | 29.3 MB   | #######7   |  78%
#
# graphviz-2.38        | 29.3 MB   | #######7   |  78%
#
# graphviz-2.38        | 29.3 MB   | #######8   |  78%
#
# graphviz-2.38        | 29.3 MB   | #######8   |  79%
#
# graphviz-2.38        | 29.3 MB   | #######8   |  79%
#
# graphviz-2.38        | 29.3 MB   | #######9   |  79%
#
# graphviz-2.38        | 29.3 MB   | #######9   |  79%
#
# graphviz-2.38        | 29.3 MB   | #######9   |  80%
#
# graphviz-2.38        | 29.3 MB   | ########   |  80%
#
# graphviz-2.38        | 29.3 MB   | ########   |  80%
#
# graphviz-2.38        | 29.3 MB   | ########   |  80%
#
# graphviz-2.38        | 29.3 MB   | ########   |  81%
#
# graphviz-2.38        | 29.3 MB   | ########1  |  81%
#
# graphviz-2.38        | 29.3 MB   | ########1  |  81%
#
# graphviz-2.38        | 29.3 MB   | ########1  |  81%
#
# graphviz-2.38        | 29.3 MB   | ########1  |  82%
#
# graphviz-2.38        | 29.3 MB   | ########1  |  82%
#
# graphviz-2.38        | 29.3 MB   | ########2  |  82%
#
# graphviz-2.38        | 29.3 MB   | ########2  |  83%
#
# graphviz-2.38        | 29.3 MB   | ########2  |  83%
#
# graphviz-2.38        | 29.3 MB   | ########2  |  83%
#
# graphviz-2.38        | 29.3 MB   | ########3  |  83%
#
# graphviz-2.38        | 29.3 MB   | ########3  |  84%
#
# graphviz-2.38        | 29.3 MB   | ########3  |  84%
#
# graphviz-2.38        | 29.3 MB   | ########3  |  84%
#
# graphviz-2.38        | 29.3 MB   | ########4  |  84%
#
# graphviz-2.38        | 29.3 MB   | ########4  |  85%
#
# graphviz-2.38        | 29.3 MB   | ########4  |  85%
#
# graphviz-2.38        | 29.3 MB   | ########4  |  85%
#
# graphviz-2.38        | 29.3 MB   | ########5  |  85%
#
# graphviz-2.38        | 29.3 MB   | ########5  |  85%
#
# graphviz-2.38        | 29.3 MB   | ########5  |  85%
#
# graphviz-2.38        | 29.3 MB   | ########5  |  86%
#
# graphviz-2.38        | 29.3 MB   | ########5  |  86%
#
# graphviz-2.38        | 29.3 MB   | ########6  |  86%
#
# graphviz-2.38        | 29.3 MB   | ########6  |  86%
#
# graphviz-2.38        | 29.3 MB   | ########6  |  86%
#
# graphviz-2.38        | 29.3 MB   | ########6  |  87%
#
# graphviz-2.38        | 29.3 MB   | ########7  |  87%
#
# graphviz-2.38        | 29.3 MB   | ########7  |  87%
#
# graphviz-2.38        | 29.3 MB   | ########7  |  88%
#
# graphviz-2.38        | 29.3 MB   | ########7  |  88%
#
# graphviz-2.38        | 29.3 MB   | ########8  |  88%
#
# graphviz-2.38        | 29.3 MB   | ########8  |  88%
#
# graphviz-2.38        | 29.3 MB   | ########8  |  89%
#
# graphviz-2.38        | 29.3 MB   | ########8  |  89%
#
# graphviz-2.38        | 29.3 MB   | ########9  |  89%
#
# graphviz-2.38        | 29.3 MB   | ########9  |  90%
#
# graphviz-2.38        | 29.3 MB   | ########9  |  90%
#
# graphviz-2.38        | 29.3 MB   | #########  |  90%
#
# graphviz-2.38        | 29.3 MB   | #########  |  91%
#
# graphviz-2.38        | 29.3 MB   | #########  |  91%
#
# graphviz-2.38        | 29.3 MB   | #########1 |  91%
#
# graphviz-2.38        | 29.3 MB   | #########1 |  91%
#
# graphviz-2.38        | 29.3 MB   | #########1 |  91%
#
# graphviz-2.38        | 29.3 MB   | #########1 |  92%
#
# graphviz-2.38        | 29.3 MB   | #########1 |  92%
#
# graphviz-2.38        | 29.3 MB   | #########2 |  92%
#
# graphviz-2.38        | 29.3 MB   | #########2 |  93%
#
# graphviz-2.38        | 29.3 MB   | #########2 |  93%
#
# graphviz-2.38        | 29.3 MB   | #########3 |  93%
#
# graphviz-2.38        | 29.3 MB   | #########3 |  94%
#
# graphviz-2.38        | 29.3 MB   | #########3 |  94%
#
# graphviz-2.38        | 29.3 MB   | #########4 |  94%
#
# graphviz-2.38        | 29.3 MB   | #########4 |  94%
#
# graphviz-2.38        | 29.3 MB   | #########4 |  95%
#
# graphviz-2.38        | 29.3 MB   | #########5 |  95%
#
# graphviz-2.38        | 29.3 MB   | #########5 |  95%
#
# graphviz-2.38        | 29.3 MB   | #########5 |  96%
#
# graphviz-2.38        | 29.3 MB   | #########5 |  96%
#
# graphviz-2.38        | 29.3 MB   | #########6 |  96%
#
# graphviz-2.38        | 29.3 MB   | #########6 |  96%
#
# graphviz-2.38        | 29.3 MB   | #########6 |  97%
#
# graphviz-2.38        | 29.3 MB   | #########6 |  97%
#
# graphviz-2.38        | 29.3 MB   | #########7 |  97%
#
# graphviz-2.38        | 29.3 MB   | #########7 |  97%
#
# graphviz-2.38        | 29.3 MB   | #########7 |  98%
#
# graphviz-2.38        | 29.3 MB   | #########7 |  98%
#
# graphviz-2.38        | 29.3 MB   | #########8 |  98%
#
# graphviz-2.38        | 29.3 MB   | #########8 |  98%
#
# graphviz-2.38        | 29.3 MB   | #########8 |  99%
#
# graphviz-2.38        | 29.3 MB   | #########8 |  99%
#
# graphviz-2.38        | 29.3 MB   | #########9 |  99%
#
# graphviz-2.38        | 29.3 MB   | #########9 |  99%
#
# graphviz-2.38        | 29.3 MB   | #########9 |  99%
#
# graphviz-2.38        | 29.3 MB   | #########9 | 100%
#
# graphviz-2.38        | 29.3 MB   | ########## | 100%
#
# graphviz-2.38        | 29.3 MB   | ########## | 100%
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages (0.20.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -otobuf (c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -otobuf (c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\xxalh\miniconda3\envs\tensorflow\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\xxalh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
#
# [notice] A new release of pip is available: 23.1.1 -> 23.1.2
# [notice] To update, run: C:\Users\xxalh\miniconda3\envs\tensorflow\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import tensorflow as tf

# %%
import os
import pathlib
import time
import datetime
import sys
from matplotlib import pyplot as plt
from IPython import display

# %%
import tensorflow_datasets as tfds

# %%
# %run "D:\on Going projects\PBL Final project\lib\binvox-rw-py\binvox_rw.py"
# Out:
# **********************************************************************
# File "D:\on Going projects\PBL Final project\lib\binvox-rw-py\binvox_rw.py", line 25, in __main__
# Failed example:
#     with open('chair.binvox', 'rb') as f:
#         m1 = binvox_rw.read_as_3d_array(f)
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\Users\xxalh\miniconda3\envs\tensorflow\lib\doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__[2]>", line 1, in <module>
#         with open('chair.binvox', 'rb') as f:
#     FileNotFoundError: [Errno 2] No such file or directory: 'chair.binvox'
# **********************************************************************
# File "D:\on Going projects\PBL Final project\lib\binvox-rw-py\binvox_rw.py", line 28, in __main__
# Failed example:
#     m1.dims
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\Users\xxalh\miniconda3\envs\tensorflow\lib\doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__[3]>", line 1, in <module>
#         m1.dims
#     NameError: name 'm1' is not defined
# **********************************************************************
# File "D:\on Going projects\PBL Final project\lib\binvox-rw-py\binvox_rw.py", line 30, in __main__
# Failed example:
#     round(m1.scale,3)
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\Users\xxalh\miniconda3\envs\tensorflow\lib\doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__[4]>", line 1, in <module>
#         round(m1.scale,3)
#     NameError: name 'm1' is not defined
# **********************************************************************
# File "D:\on Going projects\PBL Final project\lib\binvox-rw-py\binvox_rw.py", line 32, in __main__
# Failed example:
#     m1.translate
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\Users\xxalh\miniconda3\envs\tensorflow\lib\doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__[5]>", line 1, in <module>
#         m1.translate
#     NameError: name 'm1' is not defined
# **********************************************************************
# File "D:\on Going projects\PBL Final project\lib\binvox-rw-py\binvox_rw.py", line 34, in __main__
# Failed example:
#     with open('chair_out.binvox', 'wb') as f:
#         m1.write(f)
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\Users\xxalh\miniconda3\envs\tensorflow\lib\doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__[6]>", line 2, in <module>
#         m1.write(f)
#     NameError: name 'm1' is not defined
# **********************************************************************
# File "D:\on Going projects\PBL Final project\lib\binvox-rw-py\binvox_rw.py", line 37, in __main__
# Failed example:
#     with open('chair_out.binvox', 'rb') as f:
#         m2 = binvox_rw.read_as_3d_array(f)
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\Users\xxalh\miniconda3\envs\tensorflow\lib\doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__[7]>", line 2, in <module>
#         m2 = binvox_rw.read_as_3d_array(f)
#       File "D:\on Going projects\PBL Final project\lib\binvox-rw-py\binvox_rw.py", line 131, in read_as_3d_array
#         dims, translate, scale = read_header(fp)
#       File "D:\on Going projects\PBL Final project\lib\binvox-rw-py\binvox_rw.py", line 112, in read_header
#         raise IOError('Not a binvox file')
#     OSError: Not a binvox file
# **********************************************************************
# File "D:\on Going projects\PBL Final project\lib\binvox-rw-py\binvox_rw.py", line 40, in __main__
# Failed example:
#     m1.dims==m2.dims
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\Users\xxalh\miniconda3\envs\tensorflow\lib\doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__[8]>", line 1, in <module>
#         m1.dims==m2.dims
#     NameError: name 'm1' is not defined
# **********************************************************************
# File "D:\on Going projects\PBL Final project\lib\binvox-rw-py\binvox_rw.py", line 42, in __main__
# Failed example:
#     m1.scale==m2.scale
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\Users\xxalh\miniconda3\envs\tensorflow\lib\doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__[9]>", line 1, in <module>
#         m1.scale==m2.scale
#     NameError: name 'm1' is not defined
# **********************************************************************
# File "D:\on Going projects\PBL Final project\lib\binvox-rw-py\binvox_rw.py", line 44, in __main__
# Failed example:
#     m1.translate==m2.translate
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\Users\xxalh\miniconda3\envs\tensorflow\lib\doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__[10]>", line 1, in <module>
#         m1.translate==m2.translate
#     NameError: name 'm1' is not defined
# **********************************************************************
# File "D:\on Going projects\PBL Final project\lib\binvox-rw-py\binvox_rw.py", line 46, in __main__
# Failed example:
#     np.all(m1.data==m2.data)
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\Users\xxalh\miniconda3\envs\tensorflow\lib\doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__[11]>", line 1, in <module>
#         np.all(m1.data==m2.data)
#     NameError: name 'm1' is not defined
# **********************************************************************
# File "D:\on Going projects\PBL Final project\lib\binvox-rw-py\binvox_rw.py", line 49, in __main__
# Failed example:
#     with open('chair.binvox', 'rb') as f:
#         md = binvox_rw.read_as_3d_array(f)
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\Users\xxalh\miniconda3\envs\tensorflow\lib\doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__[12]>", line 1, in <module>
#         with open('chair.binvox', 'rb') as f:
#     FileNotFoundError: [Errno 2] No such file or directory: 'chair.binvox'
# **********************************************************************
# File "D:\on Going projects\PBL Final project\lib\binvox-rw-py\binvox_rw.py", line 52, in __main__
# Failed example:
#     with open('chair.binvox', 'rb') as f:
#         ms = binvox_rw.read_as_coord_array(f)
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\Users\xxalh\miniconda3\envs\tensorflow\lib\doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__[13]>", line 1, in <module>
#         with open('chair.binvox', 'rb') as f:
#     FileNotFoundError: [Errno 2] No such file or directory: 'chair.binvox'
# **********************************************************************
# File "D:\on Going projects\PBL Final project\lib\binvox-rw-py\binvox_rw.py", line 55, in __main__
# Failed example:
#     data_ds = binvox_rw.dense_to_sparse(md.data)
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\Users\xxalh\miniconda3\envs\tensorflow\lib\doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__[14]>", line 1, in <module>
#         data_ds = binvox_rw.dense_to_sparse(md.data)
#     NameError: name 'md' is not defined
# **********************************************************************
# File "D:\on Going projects\PBL Final project\lib\binvox-rw-py\binvox_rw.py", line 56, in __main__
# Failed example:
#     data_sd = binvox_rw.sparse_to_dense(ms.data, 32)
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\Users\xxalh\miniconda3\envs\tensorflow\lib\doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__[15]>", line 1, in <module>
#         data_sd = binvox_rw.sparse_to_dense(ms.data, 32)
#     NameError: name 'ms' is not defined
# **********************************************************************
# File "D:\on Going projects\PBL Final project\lib\binvox-rw-py\binvox_rw.py", line 57, in __main__
# Failed example:
#     np.all(data_sd==md.data)
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\Users\xxalh\miniconda3\envs\tensorflow\lib\doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__[16]>", line 1, in <module>
#         np.all(data_sd==md.data)
#     NameError: name 'data_sd' is not defined
# **********************************************************************
# File "D:\on Going projects\PBL Final project\lib\binvox-rw-py\binvox_rw.py", line 61, in __main__
# Failed example:
#     np.all(ms.data[:, np.lexsort(ms.data)] == data_ds[:, np.lexsort(data_ds)])
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\Users\xxalh\miniconda3\envs\tensorflow\lib\doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__[17]>", line 1, in <module>
#         np.all(ms.data[:, np.lexsort(ms.data)] == data_ds[:, np.lexsort(data_ds)])
#     NameError: name 'ms' is not defined
# **********************************************************************
# 1 items had failures:
#   16 of  18 in __main__
# ***Test Failed*** 16 failures.

# %%
# %run "D:\on Going projects\PBL Final project\file_management.py"

# %%
#limiting the consumption of the gpu
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
print(load3DFile(str(70),False).data.shape)
# Out:
# (128, 128, 128)

# %% [markdown]
# # Taking screenShot from the 3d objects that we have

# %%
data_dir = pathlib.Path(PATH+"/Data/images/")

# %%
data_3d_dir = pathlib.Path(PATH+"/Data/temp/")

# %%
for filename in os.listdir(data_3d_dir):
    print(filename)
# Out:
# 1.binvox
# 10.binvox
# 100.binvox
# 1000.binvox
# 1001.binvox
# 1002.binvox
# 1003.binvox
# 1004.binvox
# 1005.binvox
# 1007.binvox
# 1008.binvox
# 1009.binvox
# 101.binvox
# 1010.binvox
# 1011.binvox
# 1012.binvox
# 1013.binvox
# 1014.binvox
# 1015.binvox
# 1016.binvox
# 24.binvox
# 240.binvox
# 241.binvox
# 242.binvox
# 243.binvox
# 244.binvox
# 245.binvox
# 246.binvox
# 247.binvox
# 248.binvox
# 249.binvox
# 25.binvox
# 250.binvox
# 251.binvox
# 252.binvox
# 253.binvox
# 254.binvox
# 255.binvox
# 256.binvox
# 257.binvox
# 258.binvox
# 259.binvox
# 26.binvox
# 260.binvox
# 261.binvox
# 262.binvox
# 263.binvox
# 264.binvox
# 265.binvox
# 266.binvox
# 267.binvox
# 268.binvox
# 269.binvox
# 27.binvox
# 270.binvox
# 271.binvox
# 272.binvox
# 273.binvox
# 274.binvox
# 275.binvox
# 276.binvox
# 277.binvox
# 278.binvox
# 279.binvox
# 28.binvox
# 280.binvox
# 281.binvox
# 282.binvox
# 283.binvox
# 284.binvox
# 285.binvox
# 286.binvox
# 287.binvox
# 288.binvox
# 289.binvox
# 29.binvox
# 290.binvox
# 291.binvox
# 292.binvox
# 293.binvox
# 294.binvox
# 295.binvox
# 296.binvox
# 297.binvox
# 298.binvox
# 299.binvox
# 3.binvox
# 30.binvox
# 300.binvox
# 301.binvox
# 302.binvox
# 303.binvox
# 304.binvox
# 305.binvox
# 306.binvox
# 307.binvox
# 308.binvox
# 309.binvox
# 31.binvox
# 310.binvox
# 311.binvox
# 312.binvox
# 313.binvox
# 314.binvox
# 315.binvox
# 316.binvox
# 317.binvox
# 318.binvox
# 319.binvox
# 32.binvox
# 320.binvox
# 321.binvox
# 322.binvox
# 323.binvox
# 324.binvox
# 325.binvox
# 326.binvox
# 327.binvox
# 328.binvox
# 329.binvox
# 33.binvox
# 330.binvox
# 331.binvox
# 332.binvox
# 333.binvox
# 334.binvox
# 335.binvox
# 336.binvox
# 337.binvox
# 338.binvox
# 339.binvox
# 34.binvox
# 340.binvox
# 341.binvox
# 342.binvox
# 343.binvox
# 344.binvox
# 345.binvox
# 346.binvox
# 347.binvox
# 348.binvox
# 349.binvox
# 35.binvox
# 350.binvox
# 351.binvox
# 352.binvox
# 353.binvox
# 354.binvox
# 355.binvox
# 356.binvox
# 357.binvox
# 358.binvox
# 359.binvox
# 36.binvox
# 360.binvox
# 361.binvox
# 362.binvox
# 363.binvox
# 364.binvox
# 365.binvox
# 366.binvox
# 367.binvox
# 368.binvox
# 369.binvox
# 37.binvox
# 370.binvox
# 371.binvox
# 372.binvox
# 373.binvox
# 374.binvox
# 375.binvox
# 376.binvox
# 377.binvox
# 378.binvox
# 379.binvox
# 38.binvox
# 380.binvox
# 381.binvox
# 382.binvox
# 383.binvox
# 384.binvox
# 385.binvox
# 386.binvox
# 387.binvox
# 388.binvox
# 389.binvox
# 39.binvox
# 390.binvox
# 391.binvox
# 392.binvox
# 393.binvox
# 394.binvox
# 395.binvox
# 396.binvox
# 397.binvox
# 398.binvox
# 399.binvox
# 4.binvox
# 40.binvox
# 400.binvox
# 401.binvox
# 402.binvox
# 403.binvox
# 404.binvox
# 405.binvox
# 406.binvox
# 407.binvox
# 408.binvox
# 409.binvox
# 41.binvox
# 410.binvox
# 411.binvox
# 412.binvox
# 413.binvox
# 414.binvox
# 415.binvox
# 416.binvox
# 417.binvox
# 418.binvox
# 419.binvox
# 42.binvox
# 420.binvox
# 421.binvox
# 422.binvox
# 423.binvox
# 424.binvox
# 425.binvox
# 426.binvox
# 427.binvox
# 428.binvox
# 429.binvox
# 43.binvox
# 430.binvox
# 431.binvox
# 432.binvox
# 433.binvox
# 434.binvox
# 435.binvox
# 436.binvox
# 437.binvox
# 438.binvox
# 439.binvox
# 44.binvox
# 440.binvox
# 441.binvox
# 442.binvox
# 443.binvox
# 444.binvox
# 445.binvox
# 446.binvox
# 447.binvox
# 448.binvox
# 449.binvox
# 45.binvox
# 450.binvox
# 451.binvox
# 452.binvox
# 453.binvox
# 454.binvox
# 455.binvox
# 456.binvox
# 457.binvox
# 458.binvox
# 459.binvox
# 46.binvox
# 460.binvox
# 461.binvox
# 462.binvox
# 463.binvox
# 464.binvox
# 465.binvox
# 466.binvox
# 467.binvox
# 468.binvox
# 469.binvox
# 47.binvox
# 470.binvox
# 471.binvox
# 472.binvox
# 473.binvox
# 474.binvox
# 475.binvox
# 476.binvox
# 477.binvox
# 479.binvox
# 48.binvox
# 480.binvox
# 481.binvox
# 482.binvox
# 483.binvox
# 484.binvox
# 485.binvox
# 486.binvox
# 487.binvox
# 488.binvox
# 489.binvox
# 49.binvox
# 490.binvox
# 491.binvox
# 492.binvox
# 493.binvox
# 494.binvox
# 495.binvox
# 496.binvox
# 497.binvox
# 498.binvox
# 499.binvox
# 5.binvox
# 50.binvox
# 500.binvox
# 501.binvox
# 502.binvox
# 503.binvox
# 504.binvox
# 505.binvox
# 506.binvox
# 507.binvox
# 508.binvox
# 509.binvox
# 51.binvox
# 510.binvox
# 511.binvox
# 512.binvox
# 513.binvox
# 514.binvox
# 515.binvox
# 516.binvox
# 517.binvox
# 518.binvox
# 519.binvox
# 52.binvox
# 520.binvox
# 521.binvox
# 522.binvox
# 523.binvox
# 524.binvox
# 525.binvox
# 526.binvox
# 527.binvox
# 528.binvox
# 529.binvox
# 53.binvox
# 530.binvox
# 531.binvox
# 532.binvox
# 533.binvox
# 534.binvox
# 535.binvox
# 536.binvox
# 537.binvox
# 538.binvox
# 539.binvox
# 54.binvox
# 540.binvox
# 541.binvox
# 542.binvox
# 543.binvox
# 544.binvox
# 545.binvox
# 546.binvox
# 547.binvox
# 548.binvox
# 549.binvox
# 55.binvox
# 550.binvox
# 551.binvox
# 552.binvox
# 553.binvox
# 554.binvox
# 555.binvox
# 556.binvox
# 557.binvox
# 558.binvox
# 559.binvox
# 56.binvox
# 560.binvox
# 561.binvox
# 562.binvox
# 563.binvox
# 564.binvox
# 565.binvox
# 566.binvox
# 567.binvox
# 568.binvox
# 569.binvox
# 57.binvox
# 570.binvox
# 571.binvox
# 572.binvox
# 573.binvox
# 574.binvox
# 575.binvox
# 576.binvox
# 577.binvox
# 578.binvox
# 579.binvox
# 58.binvox
# 580.binvox
# 581.binvox
# 582.binvox
# 583.binvox
# 584.binvox
# 585.binvox
# 586.binvox
# 587.binvox
# 588.binvox
# 589.binvox
# 59.binvox
# 590.binvox
# 591.binvox
# 592.binvox
# 593.binvox
# 594.binvox
# 595.binvox
# 596.binvox
# 597.binvox
# 598.binvox
# 599.binvox
# 6.binvox
# 60.binvox
# 600.binvox
# 601.binvox
# 602.binvox
# 603.binvox
# 604.binvox
# 605.binvox
# 606.binvox
# 607.binvox
# 608.binvox
# 609.binvox
# 61.binvox
# 610.binvox
# 611.binvox
# 612.binvox
# 613.binvox
# 614.binvox
# 615.binvox
# 616.binvox
# 617.binvox
# 618.binvox
# 619.binvox
# 62.binvox
# 620.binvox
# 621.binvox
# 622.binvox
# 623.binvox
# 624.binvox
# 625.binvox
# 626.binvox
# 627.binvox
# 628.binvox
# 629.binvox
# 63.binvox
# 630.binvox
# 631.binvox
# 632.binvox
# 633.binvox
# 634.binvox
# 635.binvox
# 636.binvox
# 637.binvox
# 638.binvox
# 639.binvox
# 64.binvox
# 640.binvox
# 641.binvox
# 642.binvox
# 643.binvox
# 644.binvox
# 645.binvox
# 646.binvox
# 647.binvox
# 648.binvox
# 649.binvox
# 65.binvox
# 650.binvox
# 651.binvox
# 652.binvox
# 653.binvox
# 654.binvox
# 655.binvox
# 656.binvox
# 657.binvox
# 658.binvox
# 659.binvox
# 66.binvox
# 660.binvox
# 661.binvox
# 662.binvox
# 663.binvox
# 664.binvox
# 665.binvox
# 666.binvox
# 667.binvox
# 668.binvox
# 669.binvox
# 67.binvox
# 670.binvox
# 671.binvox
# 672.binvox
# 673.binvox
# 674.binvox
# 675.binvox
# 676.binvox
# 677.binvox
# 678.binvox
# 679.binvox
# 68.binvox
# 680.binvox
# 681.binvox
# 682.binvox
# 683.binvox
# 684.binvox
# 685.binvox
# 686.binvox
# 687.binvox
# 688.binvox
# 689.binvox
# 69.binvox
# 690.binvox
# 691.binvox
# 692.binvox
# 693.binvox
# 694.binvox
# 695.binvox
# 696.binvox
# 697.binvox
# 698.binvox
# 699.binvox
# 7.binvox
# 70.binvox
# 700.binvox
# 701.binvox
# 702.binvox
# 703.binvox
# 704.binvox
# 705.binvox
# 707.binvox
# 708.binvox
# 709.binvox
# 71.binvox
# 710.binvox
# 711.binvox
# 712.binvox
# 713.binvox
# 714.binvox
# 715.binvox
# 716.binvox
# 717.binvox
# 718.binvox
# 719.binvox
# 72.binvox
# 720.binvox
# 721.binvox
# 722.binvox
# 723.binvox
# 724.binvox
# 725.binvox
# 726.binvox
# 727.binvox
# 728.binvox
# 729.binvox
# 73.binvox
# 730.binvox
# 731.binvox
# 732.binvox
# 733.binvox
# 734.binvox
# 735.binvox
# 736.binvox
# 737.binvox
# 738.binvox
# 739.binvox
# 74.binvox
# 740.binvox
# 741.binvox
# 742.binvox
# 743.binvox
# 744.binvox
# 745.binvox
# 746.binvox
# 747.binvox
# 748.binvox
# 749.binvox
# 75.binvox
# 750.binvox
# 751.binvox
# 752.binvox
# 753.binvox
# 754.binvox
# 755.binvox
# 756.binvox
# 757.binvox
# 758.binvox
# 759.binvox
# 76.binvox
# 760.binvox
# 761.binvox
# 762.binvox
# 763.binvox
# 764.binvox
# 765.binvox
# 766.binvox
# 767.binvox
# 768.binvox
# 769.binvox
# 77.binvox
# 770.binvox
# 771.binvox
# 772.binvox
# 773.binvox
# 774.binvox
# 775.binvox
# 776.binvox
# 777.binvox
# 778.binvox
# 779.binvox
# 78.binvox
# 780.binvox
# 781.binvox
# 782.binvox
# 783.binvox
# 784.binvox
# 785.binvox
# 786.binvox
# 787.binvox
# 788.binvox
# 789.binvox
# 79.binvox
# 790.binvox
# 791.binvox
# 792.binvox
# 793.binvox
# 794.binvox
# 795.binvox
# 797.binvox
# 798.binvox
# 799.binvox
# 8.binvox
# 80.binvox
# 800.binvox
# 801.binvox
# 802.binvox
# 803.binvox
# 804.binvox
# 805.binvox
# 806.binvox
# 807.binvox
# 808.binvox
# 809.binvox
# 81.binvox
# 810.binvox
# 811.binvox
# 812.binvox
# 813.binvox
# 814.binvox
# 815.binvox
# 816.binvox
# 817.binvox
# 818.binvox
# 819.binvox
# 82.binvox
# 820.binvox
# 821.binvox
# 822.binvox
# 823.binvox
# 824.binvox
# 825.binvox
# 826.binvox
# 827.binvox
# 828.binvox
# 829.binvox
# 83.binvox
# 830.binvox
# 831.binvox
# 832.binvox
# 833.binvox
# 834.binvox
# 835.binvox
# 836.binvox
# 837.binvox
# 838.binvox
# 839.binvox
# 84.binvox
# 840.binvox
# 841.binvox
# 842.binvox
# 843.binvox
# 844.binvox
# 845.binvox
# 846.binvox
# 847.binvox
# 848.binvox
# 849.binvox
# 85.binvox
# 850.binvox
# 851.binvox
# 852.binvox
# 853.binvox
# 854.binvox
# 855.binvox
# 856.binvox
# 857.binvox
# 858.binvox
# 859.binvox
# 86.binvox
# 860.binvox
# 861.binvox
# 862.binvox
# 863.binvox
# 864.binvox
# 865.binvox
# 866.binvox
# 867.binvox
# 868.binvox
# 869.binvox
# 87.binvox
# 870.binvox
# 871.binvox
# 872.binvox
# 873.binvox
# 874.binvox
# 875.binvox
# 876.binvox
# 877.binvox
# 878.binvox
# 879.binvox
# 88.binvox
# 880.binvox
# 881.binvox
# 882.binvox
# 883.binvox
# 884.binvox
# 885.binvox
# 886.binvox
# 887.binvox
# 888.binvox
# 889.binvox
# 89.binvox
# 890.binvox
# 891.binvox
# 892.binvox
# 893.binvox
# 894.binvox
# 895.binvox
# 896.binvox
# 897.binvox
# 898.binvox
# 899.binvox
# 9.binvox
# 90.binvox
# 900.binvox
# 901.binvox
# 902.binvox
# 903.binvox
# 904.binvox
# 905.binvox
# 906.binvox
# 907.binvox
# 908.binvox
# 909.binvox
# 91.binvox
# 910.binvox
# 911.binvox
# 912.binvox
# 913.binvox
# 914.binvox
# 915.binvox
# 916.binvox
# 917.binvox
# 918.binvox
# 919.binvox
# 92.binvox
# 920.binvox
# 921.binvox
# 922.binvox
# 923.binvox
# 924.binvox
# 925.binvox
# 926.binvox
# 927.binvox
# 928.binvox
# 929.binvox
# 93.binvox
# 930.binvox
# 931.binvox
# 932.binvox
# 933.binvox
# 934.binvox
# 935.binvox
# 936.binvox
# 937.binvox
# 938.binvox
# 939.binvox
# 94.binvox
# 940.binvox
# 941.binvox
# 942.binvox
# 943.binvox
# 944.binvox
# 945.binvox
# 946.binvox
# 947.binvox
# 948.binvox
# 949.binvox
# 95.binvox
# 950.binvox
# 951.binvox
# 952.binvox
# 953.binvox
# 954.binvox
# 955.binvox
# 956.binvox
# 957.binvox
# 958.binvox
# 959.binvox
# 96.binvox
# 960.binvox
# 961.binvox
# 962.binvox
# 963.binvox
# 964.binvox
# 965.binvox
# 966.binvox
# 968.binvox
# 969.binvox
# 97.binvox
# 970.binvox
# 971.binvox
# 972.binvox
# 973.binvox
# 974.binvox
# 975.binvox
# 976.binvox
# 977.binvox
# 978.binvox
# 979.binvox
# 98.binvox
# 980.binvox
# 981.binvox
# 982.binvox
# 983.binvox
# 984.binvox
# 985.binvox
# 986.binvox
# 987.binvox
# 988.binvox
# 989.binvox
# 99.binvox
# 990.binvox
# 991.binvox
# 992.binvox
# 993.binvox
# 994.binvox
# 995.binvox
# 996.binvox
# 997.binvox
# 998.binvox
# 999.binvox

# %%
image_dataset = tf.data.Dataset.list_files(os.path.join(data_dir, '*.png'),shuffle=False)
binvox_dataset = tf.data.Dataset.list_files(os.path.join(PATH + "/Data/temp", '*.binvox'),shuffle=False)

# %%
# Define a function to load an image and binvox file
def load_data(image_path, binvox_path):
    # Load the image file
    image = tf.io.decode_png(tf.io.read_file(image_path), channels=3)
    
    # Load the binvox file
    #I need to get the name of the binvox file corresponds to the img file and return it

    vox = load3DModel(binvox_path)

    # Convert the voxels to a binary array
    voxels = (vox.data > 0).astype(np.int32)

    return image, voxels

# %%
# Define a dataset of image and binvox pairs
dataset = tf.data.Dataset.zip((image_dataset, binvox_dataset))

# Apply the load_data function to each image/binvox pair
dataset = dataset.map(lambda x, y: tf.numpy_function(load_data, [x, y], [tf.uint8, tf.int32]), num_parallel_calls=tf.data.AUTOTUNE)

# Print the size of the dataset
print(len(dataset))
# Out:
# 1918

# %%
dataset.name = "training Ds"

# %%
dataset = dataset.shuffle(buffer_size=len(dataset))

# %%
print(dataset)
# Out:
# <ShuffleDataset element_spec=(TensorSpec(shape=<unknown>, dtype=tf.uint8, name=None), TensorSpec(shape=<unknown>, dtype=tf.int32, name=None))>

# %%
sample_image, vox  = next(iter(dataset.take(7)))

# %%
plt.figure()
plt.imshow(sample_image)

# %%
#he's going to create a fn to load the images and splite them into 2 images 
def load(image_file):
  # Read and decode an image file to a uint8 tensor
    image = tf.io.read_file(image_file)
    image = tf.io.decode_png(image)

  # Split each image tensor into two tensors:
  # - one with a real building facade image
  # - one with an architecture label image 
    
    img_array = np.array(image)
    input_image = cv2.cvtColor(img_array, cv2.COLOR_BGRA2BGR)
  # Convert both images to float32 tensors
    return input_image

# %%
# The facade training set consist of 400 images
BUFFER_SIZE = 1918
# The batch size of 1 produced better results for the U-Net in the original pix2pix experiment
BATCH_SIZE = 1
# Each image is 256x256 in size
IMG_WIDTH = 128
IMG_HEIGHT = 128

# %%
def resize(input_image, height, width):
  input_image = tf.image.resize(input_image, [height, width],
                                method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
  return input_image

# %%
import cv2

# %%
def imgToGrey(img_path):
  img = cv2.imread(img_path)
  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  return gray

# %%
# Normalizing the images to [-1, 1]
def normalize(input_image):
  input_image = (input_image / 127.5) - 1

  return input_image

# %%
inp = load(str(PATH + '/Data/images/1011.png'))
inp2 = normalize(inp)
inp3 = normalize(inp2)
# Casting to int for matplotlib to display the images
# Loop four times and get images 

lop = [inp/255,inp2,inp3]

print(inp.shape)
print(inp2.shape)
print(inp3.shape)
fig, ax = plt.subplots(ncols=3)
for idx in range(3): 
    ax[idx].imshow(lop[idx])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)

# %%
@tf.function()
def random_jitter(input_image):
  # Resizing to 286x286
  input_image = resize(input_image,IMG_WIDTH ,IMG_HEIGHT )

  return input_image

# %%
def load_image_test(image_file):
  input_image = load(image_file)
  input_image = resize(input_image,IMG_HEIGHT, IMG_WIDTH)

  return input_image

# %%
#as far as I did understand he's minipulating the training data for better trainning and to overcome the overfitting problem
def load_image_train(image_file):
  input_image = load(image_file)
  input_image = random_jitter(input_image)

  return input_image

# %%
#loading the files
train_dataset = dataset
#shuffling
train_dataset = train_dataset.shuffle(BUFFER_SIZE)
#batching
train_dataset = train_dataset.batch(BATCH_SIZE)

# %%
#will not use it for now
#getting the test images
# try:
#   test_dataset = tf.data.Dataset.list_files(str(PATH / 'testA/*.jpg'))
# except tf.errors.InvalidArgumentError:
#   test_dataset = tf.data.Dataset.list_files(str(PATH / 'testB/*.jpg'))
# test_dataset = test_dataset.map(load_image_test)
# test_dataset = test_dataset.batch(BATCH_SIZE)

# %%
OUTPUT_CHANNELS = 1 #Grey channel

# %%
def downsample(filters, size, apply_batchnorm=True):
  initializer = tf.random_normal_initializer(0., 0.02)

  result = tf.keras.Sequential()
  result.add(
      tf.keras.layers.Conv2D(filters, size, strides=2, padding='same',
                             kernel_initializer=initializer, use_bias=False))

  if apply_batchnorm:
    result.add(tf.keras.layers.BatchNormalization())

  result.add(tf.keras.layers.LeakyReLU())

  return result

# %%
def upsample(filters, size, apply_dropout=False):
  initializer = tf.random_normal_initializer(0., 0.02)

  result = tf.keras.Sequential()
  result.add(
    tf.keras.layers.Conv2DTranspose(filters, size, strides=2,
                                    padding='same',
                                    kernel_initializer=initializer,
                                    use_bias=False))

  result.add(tf.keras.layers.BatchNormalization())

  if apply_dropout:
      result.add(tf.keras.layers.Dropout(0.5))

  result.add(tf.keras.layers.ReLU())

  return result

# %%
def initializer():
  return tf.random_normal_initializer(0., 0.02)

# %%
def maxPooling2D(filters):
  model = tf.keras.Sequential()
  model.add(tf.keras.layers.MaxPooling2D(pool_size=(filters,filters),
   strides=(2, 2), padding='valid'))
  return model

# %%
def global_max_pooling():
  model = tf.keras.Sequential()
  model.add(tf.keras.layers.GlobalAveragePooling2D())
  return model

# %%
def dense_layer(size, flatten = False):  
  model = tf.keras.Sequential()
  if (flatten):
    model.add(tf.keras.layers.Flatten())
  model.add(tf.keras.layers.Dense(size, activation='relu'))
  return model

# %%
from tensorflow.keras.layers import Conv3DTranspose, Conv3D, BatchNormalization

# %%
def Generator():
    inputs = tf.keras.layers.Input(shape=(128, 128, 3))

    #upsampling
    x = inputs

    x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1',kernel_initializer=initializer())(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2',kernel_initializer=initializer())(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

    x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1',kernel_initializer=initializer())(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2',kernel_initializer=initializer())(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

    # Block 3
    x = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1',kernel_initializer=initializer())(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2',kernel_initializer=initializer())(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3',kernel_initializer=initializer())(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

    # Block 4
    x = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1',kernel_initializer=initializer())(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2',kernel_initializer=initializer())(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3',kernel_initializer=initializer())(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

    # Block 5
    x = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1',kernel_initializer=initializer())(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2',kernel_initializer=initializer())(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3',kernel_initializer=initializer())(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool')(x)

    # Flatten and FC layers
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(8192, activation='relu', name='fc1')(x)
    x = tf.keras.layers.Dense(4096, activation='relu', name='fc2')(x)


    x = tf.keras.layers.Reshape((1, 1, 1, 4096))(x)
    x = tf.reshape(x, [-1, 1, 1, 1, 4096])

    # Decoder
    x = Conv3DTranspose(filters=64, kernel_size=(3, 3, 3), activation='relu',strides=(2, 2, 2), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = Conv3DTranspose(filters=64, kernel_size=(3, 3, 3), activation='relu',strides=(2, 2, 2), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = Conv3DTranspose(filters=64, kernel_size=(3, 3, 3), activation='relu',strides=(2, 2, 2), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = Conv3DTranspose(filters=32, kernel_size=(3, 3, 3), activation='relu',strides=(2, 2, 2), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = Conv3DTranspose(filters=32, kernel_size=(3, 3, 3), activation='relu',strides=(2, 2, 2), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = Conv3DTranspose(filters=24, kernel_size=(3, 3, 3), activation='relu',strides=(1, 1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = Conv3D(filters=1, kernel_size=(3, 3, 3), strides=(1, 1, 1), padding='same')(x)


    return tf.keras.Model(inputs=inputs, outputs=x)

# %%
generator = Generator()

# %%
generator.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 128, 128, 64)      1792
#
#  batch_normalization (BatchN  (None, 128, 128, 64)     256
#  ormalization)
#
#  block1_conv2 (Conv2D)       (None, 128, 128, 64)      36928
#
#  batch_normalization_1 (Batc  (None, 128, 128, 64)     256
#  hNormalization)
#
#  block1_pool (MaxPooling2D)  (None, 64, 64, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 64, 64, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 64, 64, 128)      512
#  hNormalization)
#
#  block2_conv2 (Conv2D)       (None, 64, 64, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 64, 64, 128)      512
#  hNormalization)
#
#  block2_pool (MaxPooling2D)  (None, 32, 32, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 32, 32, 256)       295168
#
#  batch_normalization_4 (Batc  (None, 32, 32, 256)      1024
#  hNormalization)
#
#  block3_conv2 (Conv2D)       (None, 32, 32, 256)       590080
#
#  batch_normalization_5 (Batc  (None, 32, 32, 256)      1024
#  hNormalization)
#
#  block3_conv3 (Conv2D)       (None, 32, 32, 256)       590080
#
#  batch_normalization_6 (Batc  (None, 32, 32, 256)      1024
#  hNormalization)
#
#  block3_pool (MaxPooling2D)  (None, 16, 16, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 16, 16, 512)       1180160
#
#  batch_normalization_7 (Batc  (None, 16, 16, 512)      2048
#  hNormalization)
#
#  block4_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  batch_normalization_8 (Batc  (None, 16, 16, 512)      2048
#  hNormalization)
#
#  block4_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  batch_normalization_9 (Batc  (None, 16, 16, 512)      2048
#  hNormalization)
#
#  block4_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  batch_normalization_10 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  block5_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  batch_normalization_11 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  block5_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  batch_normalization_12 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  fc1 (Dense)                 (None, 8192)              67117056
#
#  fc2 (Dense)                 (None, 4096)              33558528
#
#  reshape (Reshape)           (None, 1, 1, 1, 4096)     0
#
#  tf.reshape (TFOpLambda)     (None, 1, 1, 1, 4096)     0
#
#  conv3d_transpose (Conv3DTra  (None, 2, 2, 2, 64)      7077952
#  nspose)
#
#  batch_normalization_13 (Bat  (None, 2, 2, 2, 64)      256
#  chNormalization)
#
#  conv3d_transpose_1 (Conv3DT  (None, 4, 4, 4, 64)      110656
#  ranspose)
#
#  batch_normalization_14 (Bat  (None, 4, 4, 4, 64)      256
#  chNormalization)
#
#  conv3d_transpose_2 (Conv3DT  (None, 8, 8, 8, 64)      110656
#  ranspose)
#
#  batch_normalization_15 (Bat  (None, 8, 8, 8, 64)      256
#  chNormalization)
#
#  conv3d_transpose_3 (Conv3DT  (None, 16, 16, 16, 32)   55328
#  ranspose)
#
#  batch_normalization_16 (Bat  (None, 16, 16, 16, 32)   128
#  chNormalization)
#
#  conv3d_transpose_4 (Conv3DT  (None, 32, 32, 32, 32)   27680
#  ranspose)
#
#  batch_normalization_17 (Bat  (None, 32, 32, 32, 32)   128
#  chNormalization)
#
#  conv3d_transpose_5 (Conv3DT  (None, 32, 32, 32, 24)   20760
#  ranspose)
#
#  batch_normalization_18 (Bat  (None, 32, 32, 32, 24)   96
#  chNormalization)
#
#  conv3d (Conv3D)             (None, 32, 32, 32, 1)     649
#
# =================================================================
# Total params: 122,811,969
# Trainable params: 122,802,961
# Non-trainable params: 9,008
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(generator, show_shapes=True, dpi=64)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
def reshape(img):
    img = np.expand_dims(img, axis=0) 
    img = np.expand_dims(img, axis=-1)
    img = np.reshape(img, (1, img.shape[1], img.shape[2],img.shape[3]))
    return img

# %%
img = load(str(PATH + '/Data/images/5.png'))
img = resize(img, 128, 128)
img = reshape(img)
gen_output = generator(img, training=False)

# %%
print(gen_output.shape)
# Out:
# (1, 32, 32, 32, 1)

# %%
from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()

# %%
gen_output = np.squeeze(gen_output)
binary_output = (gen_output > 0.5).astype(np.bool_)
saveVoxel(binary_output,"lol")

# %%
# assume output is a 3D numpy array of shape (x,y,z)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x, y, z = np.indices(binary_output.shape)

# Flatten the 3D array into a 1D array
voxels = tf.reshape(gen_output,  [32,32,32])

# Plot the voxels with a color map
ax.scatter(x, y, z, c=voxels, cmap='binary', s=15)

plt.show()

# %% [markdown]
# #Defining the loss fn of the generator

# %%
LAMBDA = 100

# %%
loss_object = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %%
#loss fn
def generator_loss(gen_output, target):
    return tf.reduce_mean(tf.square(gen_output - target))

# %%
print()

# %%
#optimizers for generator and discriminator
generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

# %%
#making a checkpoint in case of failure or pausing training
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 generator=generator)

# %%
#keeping track of the training
#The fn should outputs some generated images during the training
def generate_images(model, test_input, number):
  #save the predicted object in the local dir as a 3d object
  prediction = model(test_input, training=True)
  
  # create directory if it doesn't exist
  dir_name = "Generated Images"
  if not os.path.exists(dir_name):
      os.mkdir(dir_name)

  # save array to file
  file_name = str(number) + ".npy"
  file_path = os.path.join(dir_name, file_name)
  np.save(file_path, prediction)

# %% [markdown]
# # Logs

# %%
#logs
log_dir="logs/"

summary_writer = tf.summary.create_file_writer(
  log_dir + "fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))

# %%
#a little bit stright forward
@tf.function
def train_step(input_image, target, step):
  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    gen_output = generator(input_image, training=True)

    disc_real_output = discriminator(target, training=True)
    disc_generated_output = discriminator(gen_output, training=True)

    gen_total_loss, gen_l1_loss = generator_loss(gen_output, target)
    disc_loss = discriminator_loss(disc_real_output, disc_generated_output)

  generator_gradients = gen_tape.gradient(gen_total_loss,
                                          generator.trainable_variables)
  discriminator_gradients = disc_tape.gradient(disc_loss,
                                               discriminator.trainable_variables)

  generator_optimizer.apply_gradients(zip(generator_gradients,
                                          generator.trainable_variables))
  discriminator_optimizer.apply_gradients(zip(discriminator_gradients,
                                              discriminator.trainable_variables))

  with summary_writer.as_default():
    tf.summary.scalar('gen_total_loss', gen_total_loss, step=step//100)
    tf.summary.scalar('gen_l1_loss', gen_l1_loss, step=step//100)
    tf.summary.scalar('disc_loss', disc_loss, step=step//100)

# %%
#Every 10 steps print a dot (.).
#Every 100 steps: clear the display and run generate_images to show the progress.
#Every 1k steps: save a checkpoint.
def fit(train_ds, test_ds, steps):
  example_input = next(iter(test_ds.take(1)))
  start = time.time()

  for step, input_image in train_ds.repeat().take(steps).enumerate():
    #the next line fn is to get the name of the image in the dataset
    target = input_image in train_ds.element_spec[0].file_paths.numpy()
    if (step) % 100 == 0:
      display.clear_output(wait=True)

      if step != 0:
        print(f'Time taken for 1000 steps: {time.time()-start:.2f} sec\n')

      start = time.time()

      generate_images(generator, example_input, step)
      print(f"Step: {step//100}k")

    train_step(input_image, target, step)

    # Training step
    if (step+1) % 10 == 0:
      print('.', end='', flush=True)


    # Save (checkpoint) the model every 5k steps
    if (step + 1) % 2000 == 0:
      checkpoint.save(file_prefix=checkpoint_prefix)
